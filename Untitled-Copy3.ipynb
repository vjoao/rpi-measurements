# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0, 10, 1000)

df = pd.read_csv('jessie-lite-boot.csv')

# %%
df.head()
# Out:
#    power  current  time
# 0  0.344     66.1     5
# 1  0.344     66.1    10
# 2  0.344     66.1    15
# 3  0.344     66.1    21
# 4  0.344     66.1    26

# %%
import seaborn as sns
sns.set()

plt.rc('axes', titlesize=16)

# plt.hist(df.power, bins=5, color=sns.desaturate("green", 1))
# sns.boxplot(df.power)
plt.figure(figsize=(14, 7))
plot = sns.kdeplot(df.power, shade=True)
plot.set_xlabel('Potência (W)')
plot.set_title('Raspbian Jessie Lite - Histograma de potência na inicialização (20 segundos)')

# sns.distplot(df.power)
# sns.violinplot(df.current)
# sns.kdeplot(df.power, df.current, cmap=sns.cubehelix_palette(light=1, as_cmap=True))
# Out:
# Text(0.5,1,'Raspbian Jessie Lite - Histograma de potência na inicialização (20 segundos)')

# %%
plot = df.set_index('time').power.plot(title='Raspbian Jessie Lite - Consumo na inicialização', figsize=(14,7))
plot.set_xlabel('Tempo (ms)')
plot.set_ylabel('Potência (W)')
# Out:
# Text(0,0.5,'Potência (W)')

# %%
df.head()
# Out:
#    power  current  time
# 0  0.226     43.5     5
# 1  0.226     43.5    10
# 2  0.226     43.5    15
# 3  0.226     43.5    20
# 4  0.226     43.5    25

# %%
df.mean()
# Out:
# power         1.025029
# current     199.751020
# time       9957.030287
# dtype: float64

# %%
df.to_csv('jessie-lite-boot.csv')

# %%
df = pd.read_csv('jessie-lite-boot-network.csv')

# %%
df.mean()
# Out:
# power         1.116462
# current     220.738612
# time       9957.518091
# dtype: float64

# %%
df.head()
# Out:
#             time
# 0.276 53.1     5
#       53.1    10
#       53.1    15
#       53.1    20
#       53.1    25

# %%
df = pd.read_csv('jessie-lite-boot-wifi.csv')
df.mean()
# Out:
# power         1.123006
# current     218.136635
# time       9956.265076
# dtype: float64
