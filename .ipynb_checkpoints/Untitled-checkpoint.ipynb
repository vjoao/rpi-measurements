# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0, 10, 1000)

df = pd.read_csv('output.tsv', '\t')

# %%
import seaborn as sns
sns.set()

# plt.hist(df.power, bins=5, color=sns.desaturate("green", 1))
# sns.boxplot(df.power)
plot = sns.kdeplot(df.power, shade=True)
plot.set_xlabel('Potência (W)')

# sns.distplot(df.power)
# sns.violinplot(df.current)
# sns.kdeplot(df.power, df.current, cmap=sns.cubehelix_palette(light=1, as_cmap=True))
# Out:
# Text(0.5,0,'Potência (W)')

# %%
plot = df.set_index('time').power.plot(title='Consumo na inicialização', figsize=(20,10))
plot.set_xlabel('Tempo (ms)')
plot.set_ylabel('Potência (W)')
# Out:
# Text(0,0.5,'Potência (W)')

# %%
df.head()
# Out:
#    power  current  time
# 0  0.118     22.6     5
# 1  0.118     22.6    10
# 2  0.118     22.6    15
# 3  0.118     22.6    19
# 4  0.118     22.6    24

# %%
df.max()
# Out:
# power          1.99800
# current      392.89999
# time       10001.00000
# dtype: float64
